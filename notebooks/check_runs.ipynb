# %%
import wandb
import pandas as pd

from notebooks.utils import WANDB_PROJECT

# %%
merge_keys = ["batch_size", "lr", "mixing_shift", "layers", "hidden_size", "beta2"]

# %%
scaffold = """ray job submit --no-wait --address "{address}" --working-dir . --runtime-env-json='{{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}}' -- TPU_VERSION={tpu_version} TPU_POD_COUNT={tpu_count} python"""

zone_to_address = {
    "asia-northeast1-b": "$RAY_ASIA_NORTHEAST1_B",
    "europe-west4-a": "$RAY_EU_WEST4_A",
    "us-central1-a": "$RAY_US_CENTRAL1_A",
    "us-east1-d": "$RAY_US_EAST1_D",
    "us-east5-a": "$RAY_US_EAST5_A",
    "us-east5-b": "$RAY_US_EAST5_B",
}

def format_resume_command(row):
    base_cmd = row["command"]
    if pd.isna(base_cmd):
        return None
    wandb_id = row["wandb_id"]
    tpu_zone = row["tpu_zone"]
    tpu_version = row["tpu_version"]
    tpu_count = int(row["tpu_count"])
    max_training_steps = int(row["target_steps"])
    if "--max_training_steps" in base_cmd:
        parts = base_cmd.split("--max_training_steps", 1)
        parts = [parts[0].strip(), f"--max_training_steps {max_training_steps}", parts[1].strip().split(" ", 1)[1]]
        base_cmd = " ".join(parts).strip()
    if "--resume_wandb_id" not in base_cmd and not pd.isna(wandb_id):
        base_cmd = f"{base_cmd} --resume_wandb_id {wandb_id}"
    if "--resume_wandb_id" not in base_cmd:
        return None
    address = zone_to_address.get(tpu_zone, "<unknown>")
    return scaffold.format(address=address, tpu_version=tpu_version, tpu_count=tpu_count) + " " + base_cmd.strip()

def format_command(row):
    noise_label = {
        -1000.0: "noise_mask",
        -2.0: "noise_low_uniform",
        0.0: "noise_balanced",
        2.0: "noise_high_uniform",
        1000.0: "noise_uniform",
    }.get(row["mixing_shift"], "noise_unknown")

    batch_size = int(row["batch_size"])

    args = [
        ("--batch_size", batch_size),
        ("--lr", float(row["lr"])),
        ("--max_training_steps", row["target_steps"]),
        ("--num_layers", int(row["layers"])),
        ("--hidden_size", int(row["hidden_size"])),
        ("--num_attn_heads", int(row["hidden_size"]) // 64 if row["hidden_size"] <= 1024 else int(row["hidden_size"]) // 128),
        ("--max_seq_len", 2048),
        ("--cooldown_steps", 0.0),
        ("--beta2", float(row["beta2"])),
        ("--no-break_on_nan",),
        ("--wandb_name", f"gidd-L{int(row['layers'])}-D{int(row['hidden_size'])}-H{int(row['hidden_size'])//64}-N2048-bs={int(row['batch_size'])}-lr={float(row['lr'])}-{noise_label}"),
        ("--hybrid_mixing_shift", float(row["mixing_shift"])),
        ("--wandb_tags", f"crit_bs_l{int(row['layers'])}_d{int(row['hidden_size'])},{noise_label}"),
    ]
    # if not pd.isna(row["wandb_id"]):
    #     args.append(("--resume_wandb_id", row["wandb_id"]))
    return "python main_ray.py " + " ".join(" ".join(map(str, arg)) for arg in args)

# %%
from datetime import datetime, timezone
from zoneinfo import ZoneInfo

dt_local = datetime(2025, 9, 13, 21, 0, tzinfo=ZoneInfo("Europe/Zurich"))
dt_utc = dt_local.astimezone(timezone.utc)

runs = wandb.Api().runs(
    path=WANDB_PROJECT,
    filters={
        "$and": [
            {"$or": [
                {"tags": "crit_bs_l8_d512"},
                {"tags": "crit_bs_l10_d640"},
                {"tags": "crit_bs_l12_d768"},
                {"tags": "crit_bs_l16_d1024"},
                {"tags": "crit_bs_l20_d1536"},
                {"tags": "scaling_laws"},
            ]},
            {"created_at": {"$gte": dt_utc.isoformat()}}
        ],
    },
    order="+created_at",
    per_page=1000,
)
len(runs)
# Out:
# 743

# %%
from concurrent.futures import ThreadPoolExecutor, as_completed
import subprocess
import re


patterns = {
    "batch_size": re.compile(r"--batch_size (\d+)"),
    "lr": re.compile(r"--lr ([\d.]+)"),
    "layers": re.compile(r"--num_layers (\d+)"),
    "hidden_size": re.compile(r"--hidden_size (\d+)"),
    "beta2": re.compile(r"--beta2 ([\d.]+)"),
    "mixing_shift": re.compile(r"--hybrid_mixing_shift ([\-\d.]+)"),
    "tpu_zone": re.compile(r"TPU_ZONE=([a-z0-9\-]+)"),
    "tpu_version": re.compile(r"TPU_VERSION=([a-z0-9\-]+)"),
    "tpu_count": re.compile(r"TPU_POD_COUNT=(\d+)"),
}

def parse_command(command):
    parsed = {}
    for key, pattern in patterns.items():
        match = pattern.search(command)
        if match:
            val = match.group(1)
            try:
                parsed[key] = float(val) if '.' in val else int(val)
            except ValueError:
                parsed[key] = val
    return parsed

addresses = {
    "asia-northeast1-b": "$RAY_ASIA_NORTHEAST1_B",
    "europe-west4-a": "$RAY_EU_WEST4_A",
    "us-central1-a": "$RAY_US_CENTRAL1_A",
    "us-east1-d": "$RAY_US_EAST1_D",
    "us-east5-a": "$RAY_US_EAST5_A",
    "us-east5-b": "$RAY_US_EAST5_B",
}

# for address in addresses:
#     output = subprocess.run(["zsh", "-lc", f"ray job list --address {address}"], capture_output=True, text=True)
#     print(output)
all_rows = []
with ThreadPoolExecutor(max_workers=len(addresses)) as executor:
    futures = {}
    for tpu_zone, address in addresses.items():
        cmd = f"source ~/.zshrc && ray job list --address {address}"
        futures[executor.submit(subprocess.run, cmd, shell=True, capture_output=True, text=True, executable="/bin/zsh")] = tpu_zone
    for future in as_completed(futures):
        tpu_zone = futures[future]
        output = future.result()
        # print(output)
        lines = output.stdout.splitlines()[1:]
        rows = [parse_command(x) for x in lines if "RUNNING" in x]
        for row in rows:
            row["tpu_zone"] = tpu_zone
            row["is_running"] = True
        all_rows.extend(rows)

running_df = pd.DataFrame(all_rows)
running_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
def hparams_by_bs(layers):
    hparams = {
        8: ([0.1, 0.2, 0.3], [0.99], 80000),
        16: ([0.2, 0.3, 0.5], [0.99], 80000),
        32: ([0.2, 0.3, 0.5], [0.99], 80000),
        64: ([0.3, 0.5, 1.0], [0.99], 80000),
        128: ([0.3, 0.5, 1.0], [0.99], 80000),
        256: ([0.5, 1.0], [0.98], 80000),
        512: ([0.5, 1.0, 2.0], [0.98], 40000 if layers < 20 else 80000),
        # 1024: ([1.0, 2.0], [0.98], 20000),
    }
    if layers >= 20:
        hparams[1024] = ([1.0, 2.0], [0.98], 40000)
    return hparams
target_mixing_shifts = [-1000.0, -2.0, 0.0, 2.0, 1000.0]
target_sizes = [(8, 512), (10, 640), (12, 768), (16, 1024), (20, 1536)]

rows = [
    {
        "batch_size": bs,
        "lr": lr,
        "mixing_shift": ms,
        "layers": l,
        "hidden_size": d,
        "beta2": b2,
        "target_steps": steps,
    }
    for l, d in target_sizes
    for bs, (lrs, b2s, steps) in hparams_by_bs(l).items() for lr in lrs for b2 in b2s
    for ms in target_mixing_shifts
]
needed_df = pd.DataFrame(rows)
needed_df["is_needed"] = True
len(needed_df)
# Out:
# 510

# %%
import tqdm.auto as tqdm

wandb_rows = []
for run in tqdm.tqdm(runs):
    cfg = run.config
    state = run.state
    wandb_rows.append({
        "batch_size": cfg.get("batch_size"),
        "lr": cfg.get("lr"),
        "mixing_shift": cfg.get("hybrid_mixing_shift"),
        "layers": cfg.get("num_layers"),
        "hidden_size": cfg.get("hidden_size"),
        "beta2": cfg.get("beta2"),
        "status": state,
        "wandb_id": run.id,
        "ray_id": cfg.get("ray_job_id"),
        "step": run.summary.get("_step"),
        # "is_done": run.summary.get("_step") is not None and run.summary.get("_step") >= step_targets.get(cfg.get("batch_size"), 1e6),
        "name": run.name,
        "tpu_version": cfg.get("tpu_version"),
        "tpu_zone": cfg.get("tpu_zone"),
        "tpu_count": cfg.get("tpu_pod_count"),
        "command": cfg.get("command"),
    })

wandb_df = pd.DataFrame(wandb_rows).dropna(how="any")
# Out:
#   0%|          | 0/743 [00:00<?, ?it/s]

# %%
existing_df = wandb_df
if len(running_df) > 0:
    existing_df = existing_df.merge(running_df, how="outer", on=merge_keys + ["tpu_zone", "tpu_version"], suffixes=("", "_running"))
else:
    existing_df["tpu_count_running"] = None
    existing_df["is_running"] = False
existing_df.loc[existing_df["status"].isna(), "status"] = "pending"
# existing_df.loc[existing_df["is_done"].isna(), "is_done"] = False
existing_df.loc[existing_df["tpu_count"].isna(), "tpu_count"] = existing_df.loc[existing_df["tpu_count"].isna(), "tpu_count_running"].astype(int)
existing_df
# Out:
#      batch_size   lr  mixing_shift  layers  hidden_size  beta2    status  \
# 0          16.0  0.1             0     8.0        512.0   0.99  finished
# 1          16.0  0.5             0     8.0        512.0   0.99  finished
# 2          16.0  0.3             0     8.0        512.0   0.99  finished
# 3          16.0  0.2             0     8.0        512.0   0.99  finished
# 4          16.0  0.1         -1000     8.0        512.0   0.99  finished
# ..          ...  ...           ...     ...          ...    ...       ...
# 738       512.0  1.0             2    16.0       1024.0   0.98  finished
# 739       512.0  1.0          1000    16.0       1024.0   0.98  finished
# 740       512.0  2.0         -1000    16.0       1024.0   0.98  finished
# 741       512.0  2.0            -2    16.0       1024.0   0.98  finished
# 742       512.0  2.0             0    16.0       1024.0   0.98  finished
#
#      wandb_id    ray_id      step  \
# 0    yjkfkoa1  02000000  100000.0
# 1    yvu8cfvq  05000000  100000.0
# 2    vr4hlb9a  03000000  100000.0
# 3    fcn0t3to  04000000  100000.0
# 4    q2pv9rty  72000000  100000.0
# ..        ...       ...       ...
# 738  qe4h8zgv  3e000000   40000.0
# 739  uonm8g0t  3f000000   40000.0
# 740  22vahdn7  40000000   40000.0
# 741  gasebctv  41000000   40000.0
# 742  bl9ffjnr  42000000   40000.0
#
#                                                   name tpu_version  \
# 0    gidd-L8-D512-H8-N2048-bs=16-lr=0.1-noise_balanced       v6e-8
# 1    gidd-L8-D512-H8-N2048-bs=16-lr=0.5-noise_balanced       v6e-8
# 2    gidd-L8-D512-H8-N2048-bs=16-lr=0.3-noise_balanced       v6e-8
# 3    gidd-L8-D512-H8-N2048-bs=16-lr=0.2-noise_balanced       v6e-8
# 4        gidd-L8-D512-H8-N2048-bs=16-lr=0.1-noise_mask       v6e-8
# ..                                                 ...         ...
# 738  gidd-L16-D1024-H16-N2048-bs=512-lr=1.0-noise_h...      v5p-32
# 739  gidd-L16-D1024-H16-N2048-bs=512-lr=1.0-noise_u...      v5p-32
# 740  gidd-L16-D1024-H16-N2048-bs=512-lr=2.0-noise_mask      v5p-32
# 741  gidd-L16-D1024-H16-N2048-bs=512-lr=2.0-noise_l...      v5p-32
# 742  gidd-L16-D1024-H16-N2048-bs=512-lr=2.0-noise_b...      v5p-32
#
#               tpu_zone tpu_count  \
# 0       europe-west4-a         1
# 1       europe-west4-a         1
# 2       europe-west4-a         1
# 3       europe-west4-a         1
# 4    asia-northeast1-b         1
# ..                 ...       ...
# 738         us-east5-a         1
# 739         us-east5-a         1
# 740         us-east5-a         1
# 741         us-east5-a         1
# 742         us-east5-a         1
#
#                                                command tpu_count_running  \
# 0    main_ray.py --batch_size 16 --lr 0.1 --max_tra...              None
# 1    main_ray.py --batch_size 16 --lr 0.5 --max_tra...              None
# 2    main_ray.py --batch_size 16 --lr 0.3 --max_tra...              None
# 3    main_ray.py --batch_size 16 --lr 0.2 --max_tra...              None
# 4    main_ray.py --batch_size 16 --lr 0.1 --max_tra...              None
# ..                                                 ...               ...
# 738  main_ray.py --batch_size 512 --micro_batch_siz...              None
# 739  main_ray.py --batch_size 512 --micro_batch_siz...              None
# 740  main_ray.py --batch_size 512 --micro_batch_siz...              None
# 741  main_ray.py --batch_size 512 --micro_batch_siz...              None
# 742  main_ray.py --batch_size 512 --micro_batch_siz...              None
#
#      is_running
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ..          ...
# 738       False
# 739       False
# 740       False
# 741       False
# 742       False
#
# [670 rows x 17 columns]

# %%
df.loc[df["target_steps"].isna()]
# Out:
#      batch_size    lr  mixing_shift  layers  hidden_size  beta2    status  \
# 0           8.0  0.05       -1000.0     8.0        512.0   0.99  finished
# 1           8.0  0.05       -1000.0    12.0        768.0   0.99  finished
# 2           8.0  0.05       -1000.0    16.0       1024.0   0.99  finished
# 3           8.0  0.05          -2.0     8.0        512.0   0.99  finished
# 4           8.0  0.05          -2.0    12.0        768.0   0.99  finished
# ..          ...   ...           ...     ...          ...    ...       ...
# 529       256.0  0.30        1000.0    16.0       1024.0   0.98   crashed
# 510       256.0  0.30       -1000.0    16.0       1024.0   0.98   crashed
# 525       256.0  0.30           2.0    16.0       1024.0   0.98   crashed
# 228        32.0  0.25           0.0    20.0       1536.0   0.99   crashed
# 429       128.0  0.40           2.0    20.0       1536.0   0.99   crashed
#
#      wandb_id    ray_id      step  \
# 0    41x399b0  14000000  100000.0
# 1    s0u7gktl  19000000  100000.0
# 2    aoycq16e  1e000000  100000.0
# 3    j9sznhsd  4a000000  100000.0
# 4    7nd2xgmu  4f000000  100000.0
# ..        ...       ...       ...
# 529  ojuz7tsk  27000000    7500.0
# 510  bnzcdk4l  26000000    7150.0
# 525  e3n1n2d2  1a000000    6350.0
# 228  yzf73zxt  3b000000    3950.0
# 429  4thvhht4  43000000     250.0
#
#                                                   name tpu_version  \
# 0        gidd-L8-D512-H8-N2048-bs=8-lr=0.05-noise_mask       v6e-8
# 1      gidd-L12-D768-H12-N2048-bs=8-lr=0.05-noise_mask       v6e-8
# 2     gidd-L16-D1024-H16-N2048-bs=8-lr=0.05-noise_mask       v6e-8
# 3    gidd-L8-D512-H8-N2048-bs=8-lr=0.05-noise_low_u...       v6e-8
# 4    gidd-L12-D768-H12-N2048-bs=8-lr=0.05-noise_low...       v6e-8
# ..                                                 ...         ...
# 529  gidd-L16-D1024-H16-N2048-bs=256-lr=0.3-noise_u...      v6e-16
# 510  gidd-L16-D1024-H16-N2048-bs=256-lr=0.3-noise_mask      v6e-16
# 525  gidd-L16-D1024-H16-N2048-bs=256-lr=0.3-noise_h...      v6e-16
# 228    gidd-L20-D1536-H12-bs=32-lr=0.25-noise_balanced       v6e-8
# 429  gidd-L20-D1536-H12-bs=128-lr=0.4-noise_high_un...       v6e-8
#
#            tpu_zone tpu_count  \
# 0    europe-west4-a         1
# 1    europe-west4-a         1
# 2    europe-west4-a         1
# 3        us-east5-b         1
# 4        us-east5-b         1
# ..              ...       ...
# 529  europe-west4-a         4
# 510  europe-west4-a         4
# 525      us-east5-b         4
# 228  europe-west4-a         2
# 429  europe-west4-a         4
#
#                                                command tpu_count_running  \
# 0    main_ray.py --batch_size 8 --lr 0.05 --max_tra...              None
# 1    main_ray.py --batch_size 8 --lr 0.05 --max_tra...              None
# 2    main_ray.py --batch_size 8 --lr 0.05 --max_tra...              None
# 3    main_ray.py --batch_size 8 --lr 0.05 --max_tra...              None
# 4    main_ray.py --batch_size 8 --lr 0.05 --max_tra...              None
# ..                                                 ...               ...
# 529  main_ray.py --batch_size 256 --lr 0.3 --max_tr...              None
# 510  main_ray.py --batch_size 256 --lr 0.3 --max_tr...              None
# 525  main_ray.py --batch_size 256 --lr 0.3 --max_tr...              None
# 228  main_ray.py --batch_size 32 --lr 0.25 --max_tr...              None
# 429  main_ray.py --batch_size 128 --lr 0.4 --max_tr...              None
#
#     is_running  target_steps is_needed  is_done
# 0        False           NaN     False    False
# 1        False           NaN     False    False
# 2        False           NaN     False    False
# 3        False           NaN     False    False
# 4        False           NaN     False    False
# ..         ...           ...       ...      ...
# 529      False           NaN     False    False
# 510      False           NaN     False    False
# 525      False           NaN     False    False
# 228      False           NaN     False    False
# 429      False           NaN     False    False
#
# [125 rows x 20 columns]

# %%
df = existing_df.merge(needed_df, how="outer")
df.loc[:, "is_needed"] = df["is_needed"].fillna(False)

df.loc[df["target_steps"].isna(), "target_steps"] = 80000
df["is_done"] = False
df.loc[df["step"] >= df["target_steps"], "is_done"] = True

df.loc[df["is_running"].isna(), "is_running"] = False
df = df.sort_values(["is_done", "is_running", "step"], ascending=[False, False, False])
df = df.drop_duplicates(subset=merge_keys, keep="first", inplace=False)
df.loc[(df["status"] == "crashed") & df["is_needed"] & (df["step"].isna() | (df["step"] < 100)), "status"] = "missing"
df.loc[df["is_needed"] & df["status"].isna(), "status"] = "missing"
# df.loc[~df["wandb_id"].isna(), "status"] = df.loc[~df["wandb_id"].isna(), "status"].fillna("N/A")
df["resume_command"] = df.apply(format_resume_command, axis=1)
df["command"] = df.apply(format_command, axis=1)
df.loc[df["is_done"], "status"] = "finished"
df
# Out:
# /tmp/ipykernel_1637215/2686361429.py:2: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.loc[:, "is_needed"] = df["is_needed"].fillna(False)
#      batch_size    lr  mixing_shift  layers  hidden_size  beta2    status  \
# 0           8.0  0.05       -1000.0     8.0        512.0   0.99  finished
# 1           8.0  0.05       -1000.0    12.0        768.0   0.99  finished
# 2           8.0  0.05       -1000.0    16.0       1024.0   0.99  finished
# 3           8.0  0.05          -2.0     8.0        512.0   0.99  finished
# 4           8.0  0.05          -2.0    12.0        768.0   0.99  finished
# ..          ...   ...           ...     ...          ...    ...       ...
# 695      1024.0  2.00       -1000.0    20.0       1536.0   0.98   missing
# 696      1024.0  2.00          -2.0    20.0       1536.0   0.98   missing
# 698      1024.0  2.00           0.0    20.0       1536.0   0.98   missing
# 699      1024.0  2.00           2.0    20.0       1536.0   0.98   missing
# 700      1024.0  2.00        1000.0    20.0       1536.0   0.98   missing
#
#      wandb_id    ray_id      step  ... tpu_version        tpu_zone tpu_count  \
# 0    41x399b0  14000000  100000.0  ...       v6e-8  europe-west4-a         1
# 1    s0u7gktl  19000000  100000.0  ...       v6e-8  europe-west4-a         1
# 2    aoycq16e  1e000000  100000.0  ...       v6e-8  europe-west4-a         1
# 3    j9sznhsd  4a000000  100000.0  ...       v6e-8      us-east5-b         1
# 4    7nd2xgmu  4f000000  100000.0  ...       v6e-8      us-east5-b         1
# ..        ...       ...       ...  ...         ...             ...       ...
# 695       NaN       NaN       NaN  ...         NaN             NaN       NaN
# 696       NaN       NaN       NaN  ...         NaN             NaN       NaN
# 698       NaN       NaN       NaN  ...         NaN             NaN       NaN
# 699       NaN       NaN       NaN  ...         NaN             NaN       NaN
# 700       NaN       NaN       NaN  ...         NaN             NaN       NaN
#
#                                                command tpu_count_running  \
# 0    python main_ray.py --batch_size 8 --lr 0.05 --...              None
# 1    python main_ray.py --batch_size 8 --lr 0.05 --...              None
# 2    python main_ray.py --batch_size 8 --lr 0.05 --...              None
# 3    python main_ray.py --batch_size 8 --lr 0.05 --...              None
# 4    python main_ray.py --batch_size 8 --lr 0.05 --...              None
# ..                                                 ...               ...
# 695  python main_ray.py --batch_size 1024 --lr 2.0 ...               NaN
# 696  python main_ray.py --batch_size 1024 --lr 2.0 ...               NaN
# 698  python main_ray.py --batch_size 1024 --lr 2.0 ...               NaN
# 699  python main_ray.py --batch_size 1024 --lr 2.0 ...               NaN
# 700  python main_ray.py --batch_size 1024 --lr 2.0 ...               NaN
#
#     is_running target_steps  is_needed is_done  \
# 0        False      80000.0      False    True
# 1        False      80000.0      False    True
# 2        False      80000.0      False    True
# 3        False      80000.0      False    True
# 4        False      80000.0      False    True
# ..         ...          ...        ...     ...
# 695      False      40000.0       True   False
# 696      False      40000.0       True   False
# 698      False      40000.0       True   False
# 699      False      40000.0       True   False
# 700      False      40000.0       True   False
#
#                                         resume_command
# 0    ray job submit --no-wait --address "$RAY_EU_WE...
# 1    ray job submit --no-wait --address "$RAY_EU_WE...
# 2    ray job submit --no-wait --address "$RAY_EU_WE...
# 3    ray job submit --no-wait --address "$RAY_US_EA...
# 4    ray job submit --no-wait --address "$RAY_US_EA...
# ..                                                 ...
# 695                                               None
# 696                                               None
# 698                                               None
# 699                                               None
# 700                                               None
#
# [635 rows x 21 columns]

# %%
df.loc[df["is_needed"] == True, "is_done"].value_counts()
# Out:
# is_done
# True     336
# False    174
# Name: count, dtype: int64

# %%
notdone_df = df[(df["is_needed"]) & (~df["is_done"])]
notdone_df
# Out:
#      batch_size   lr  mixing_shift  layers  hidden_size  beta2    status  \
# 333        64.0  0.3        1000.0    20.0       1536.0   0.99   crashed
# 320        64.0  0.3           0.0    20.0       1536.0   0.99   crashed
# 534       256.0  0.5       -1000.0    16.0       1024.0   0.98   crashed
# 317        64.0  0.3           0.0    10.0        640.0   0.99   crashed
# 582       256.0  1.0           2.0    16.0       1024.0   0.98  finished
# ..          ...  ...           ...     ...          ...    ...       ...
# 695      1024.0  2.0       -1000.0    20.0       1536.0   0.98   missing
# 696      1024.0  2.0          -2.0    20.0       1536.0   0.98   missing
# 698      1024.0  2.0           0.0    20.0       1536.0   0.98   missing
# 699      1024.0  2.0           2.0    20.0       1536.0   0.98   missing
# 700      1024.0  2.0        1000.0    20.0       1536.0   0.98   missing
#
#      wandb_id    ray_id     step  ... tpu_version           tpu_zone  \
# 333  cl3rs8d7  1b000000  74450.0  ...       v6e-8  asia-northeast1-b
# 320  o9g43r2z  1a000000  66900.0  ...       v6e-8  asia-northeast1-b
# 534  l57aw9ji  19000000  57450.0  ...      v6e-16         us-east5-b
# 317  yeoig5q7  15000000  54600.0  ...       v6e-8  asia-northeast1-b
# 582  kl046drk  2a000000  52400.0  ...      v6e-16     europe-west4-a
# ..        ...       ...      ...  ...         ...                ...
# 695       NaN       NaN      NaN  ...         NaN                NaN
# 696       NaN       NaN      NaN  ...         NaN                NaN
# 698       NaN       NaN      NaN  ...         NaN                NaN
# 699       NaN       NaN      NaN  ...         NaN                NaN
# 700       NaN       NaN      NaN  ...         NaN                NaN
#
#     tpu_count                                            command  \
# 333         2  python main_ray.py --batch_size 64 --lr 0.3 --...
# 320         2  python main_ray.py --batch_size 64 --lr 0.3 --...
# 534         4  python main_ray.py --batch_size 256 --lr 0.5 -...
# 317         2  python main_ray.py --batch_size 64 --lr 0.3 --...
# 582         4  python main_ray.py --batch_size 256 --lr 1.0 -...
# ..        ...                                                ...
# 695       NaN  python main_ray.py --batch_size 1024 --lr 2.0 ...
# 696       NaN  python main_ray.py --batch_size 1024 --lr 2.0 ...
# 698       NaN  python main_ray.py --batch_size 1024 --lr 2.0 ...
# 699       NaN  python main_ray.py --batch_size 1024 --lr 2.0 ...
# 700       NaN  python main_ray.py --batch_size 1024 --lr 2.0 ...
#
#     tpu_count_running is_running target_steps  is_needed is_done  \
# 333              None      False      80000.0       True   False
# 320              None      False      80000.0       True   False
# 534              None      False      80000.0       True   False
# 317              None      False      80000.0       True   False
# 582              None      False      80000.0       True   False
# ..                ...        ...          ...        ...     ...
# 695               NaN      False      40000.0       True   False
# 696               NaN      False      40000.0       True   False
# 698               NaN      False      40000.0       True   False
# 699               NaN      False      40000.0       True   False
# 700               NaN      False      40000.0       True   False
#
#                                         resume_command
# 333  ray job submit --no-wait --address "$RAY_ASIA_...
# 320  ray job submit --no-wait --address "$RAY_ASIA_...
# 534  ray job submit --no-wait --address "$RAY_US_EA...
# 317  ray job submit --no-wait --address "$RAY_ASIA_...
# 582  ray job submit --no-wait --address "$RAY_EU_WE...
# ..                                                 ...
# 695                                               None
# 696                                               None
# 698                                               None
# 699                                               None
# 700                                               None
#
# [174 rows x 21 columns]

# %%
interrupted_df = df.loc[(df["is_done"] == False) & (df["is_running"] != True) & (df["is_needed"]) & (df["status"] != "missing")]
interrupted_df
# Out:
#      batch_size   lr  mixing_shift  layers  hidden_size  beta2    status  \
# 333        64.0  0.3        1000.0    20.0       1536.0   0.99   crashed
# 320        64.0  0.3           0.0    20.0       1536.0   0.99   crashed
# 534       256.0  0.5       -1000.0    16.0       1024.0   0.98   crashed
# 317        64.0  0.3           0.0    10.0        640.0   0.99   crashed
# 582       256.0  1.0           2.0    16.0       1024.0   0.98  finished
# ..          ...  ...           ...     ...          ...    ...       ...
# 653       512.0  1.0        1000.0    12.0        768.0   0.98   crashed
# 546       256.0  0.5           0.0    16.0       1024.0   0.98   crashed
# 625       512.0  1.0       -1000.0    12.0        768.0   0.98   crashed
# 569       256.0  1.0          -2.0    16.0       1024.0   0.98   crashed
# 613       512.0  0.5           2.0    10.0        640.0   0.98   crashed
#
#      wandb_id    ray_id     step  ... tpu_version           tpu_zone  \
# 333  cl3rs8d7  1b000000  74450.0  ...       v6e-8  asia-northeast1-b
# 320  o9g43r2z  1a000000  66900.0  ...       v6e-8  asia-northeast1-b
# 534  l57aw9ji  19000000  57450.0  ...      v6e-16         us-east5-b
# 317  yeoig5q7  15000000  54600.0  ...       v6e-8  asia-northeast1-b
# 582  kl046drk  2a000000  52400.0  ...      v6e-16     europe-west4-a
# ..        ...       ...      ...  ...         ...                ...
# 653  yytqoild  0e000000  10800.0  ...      v6e-64     europe-west4-a
# 546  yx9ds0os  17000000  10400.0  ...      v6e-64     europe-west4-a
# 625  ws67nyvz  12000000   9550.0  ...      v6e-64     europe-west4-a
# 569  76xixgci  0a000000   5300.0  ...      v6e-64         us-east5-b
# 613  9ry481b9  14000000   3400.0  ...      v6e-64     europe-west4-a
#
#     tpu_count                                            command  \
# 333         2  python main_ray.py --batch_size 64 --lr 0.3 --...
# 320         2  python main_ray.py --batch_size 64 --lr 0.3 --...
# 534         4  python main_ray.py --batch_size 256 --lr 0.5 -...
# 317         2  python main_ray.py --batch_size 64 --lr 0.3 --...
# 582         4  python main_ray.py --batch_size 256 --lr 1.0 -...
# ..        ...                                                ...
# 653         1  python main_ray.py --batch_size 512 --lr 1.0 -...
# 546         1  python main_ray.py --batch_size 256 --lr 0.5 -...
# 625         1  python main_ray.py --batch_size 512 --lr 1.0 -...
# 569         1  python main_ray.py --batch_size 256 --lr 1.0 -...
# 613         1  python main_ray.py --batch_size 512 --lr 0.5 -...
#
#     tpu_count_running is_running target_steps  is_needed is_done  \
# 333              None      False      80000.0       True   False
# 320              None      False      80000.0       True   False
# 534              None      False      80000.0       True   False
# 317              None      False      80000.0       True   False
# 582              None      False      80000.0       True   False
# ..                ...        ...          ...        ...     ...
# 653              None      False      40000.0       True   False
# 546              None      False      80000.0       True   False
# 625              None      False      40000.0       True   False
# 569              None      False      80000.0       True   False
# 613              None      False      40000.0       True   False
#
#                                         resume_command
# 333  ray job submit --no-wait --address "$RAY_ASIA_...
# 320  ray job submit --no-wait --address "$RAY_ASIA_...
# 534  ray job submit --no-wait --address "$RAY_US_EA...
# 317  ray job submit --no-wait --address "$RAY_ASIA_...
# 582  ray job submit --no-wait --address "$RAY_EU_WE...
# ..                                                 ...
# 653  ray job submit --no-wait --address "$RAY_EU_WE...
# 546  ray job submit --no-wait --address "$RAY_EU_WE...
# 625  ray job submit --no-wait --address "$RAY_EU_WE...
# 569  ray job submit --no-wait --address "$RAY_US_EA...
# 613  ray job submit --no-wait --address "$RAY_EU_WE...
#
# [143 rows x 21 columns]

# %%
inprogress_df = df.loc[(df["is_done"] == False) & (df["is_running"] == True) & (df["is_needed"])]
inprogress_df
# Out:
# Empty DataFrame
# Columns: [batch_size, lr, mixing_shift, layers, hidden_size, beta2, status, wandb_id, ray_id, step, name, tpu_version, tpu_zone, tpu_count, command, tpu_count_running, is_running, target_steps, is_needed, is_done, resume_command]
# Index: []
#
# [0 rows x 21 columns]

# %%
missing_df = df.loc[(df["status"] == "missing") & (df["is_needed"])]
missing_df
# Out:
#      batch_size   lr  mixing_shift  layers  hidden_size  beta2   status  \
# 16          8.0  0.1       -1000.0    10.0        640.0   0.99  missing
# 19          8.0  0.1       -1000.0    20.0       1536.0   0.99  missing
# 21          8.0  0.1          -2.0    10.0        640.0   0.99  missing
# 24          8.0  0.1          -2.0    20.0       1536.0   0.99  missing
# 26          8.0  0.1           0.0    10.0        640.0   0.99  missing
# 29          8.0  0.1           0.0    20.0       1536.0   0.99  missing
# 31          8.0  0.1           2.0    10.0        640.0   0.99  missing
# 34          8.0  0.1           2.0    20.0       1536.0   0.99  missing
# 36          8.0  0.1        1000.0    10.0        640.0   0.99  missing
# 39          8.0  0.1        1000.0    20.0       1536.0   0.99  missing
# 397       128.0  0.3       -1000.0    10.0        640.0   0.99  missing
# 400       128.0  0.3       -1000.0    20.0       1536.0   0.99  missing
# 403       128.0  0.3          -2.0    10.0        640.0   0.99  missing
# 406       128.0  0.3          -2.0    20.0       1536.0   0.99  missing
# 408       128.0  0.3           0.0    10.0        640.0   0.99  missing
# 412       128.0  0.3           0.0    20.0       1536.0   0.99  missing
# 414       128.0  0.3           2.0    10.0        640.0   0.99  missing
# 417       128.0  0.3           2.0    20.0       1536.0   0.99  missing
# 419       128.0  0.3        1000.0    10.0        640.0   0.99  missing
# 422       128.0  0.3        1000.0    20.0       1536.0   0.99  missing
# 638       512.0  1.0           0.0    10.0        640.0   0.98  missing
# 689      1024.0  1.0       -1000.0    20.0       1536.0   0.98  missing
# 690      1024.0  1.0          -2.0    20.0       1536.0   0.98  missing
# 692      1024.0  1.0           0.0    20.0       1536.0   0.98  missing
# 693      1024.0  1.0           2.0    20.0       1536.0   0.98  missing
# 694      1024.0  1.0        1000.0    20.0       1536.0   0.98  missing
# 695      1024.0  2.0       -1000.0    20.0       1536.0   0.98  missing
# 696      1024.0  2.0          -2.0    20.0       1536.0   0.98  missing
# 698      1024.0  2.0           0.0    20.0       1536.0   0.98  missing
# 699      1024.0  2.0           2.0    20.0       1536.0   0.98  missing
# 700      1024.0  2.0        1000.0    20.0       1536.0   0.98  missing
#
#     wandb_id ray_id  step  ... tpu_version tpu_zone tpu_count  \
# 16       NaN    NaN   NaN  ...         NaN      NaN       NaN
# 19       NaN    NaN   NaN  ...         NaN      NaN       NaN
# 21       NaN    NaN   NaN  ...         NaN      NaN       NaN
# 24       NaN    NaN   NaN  ...         NaN      NaN       NaN
# 26       NaN    NaN   NaN  ...         NaN      NaN       NaN
# 29       NaN    NaN   NaN  ...         NaN      NaN       NaN
# 31       NaN    NaN   NaN  ...         NaN      NaN       NaN
# 34       NaN    NaN   NaN  ...         NaN      NaN       NaN
# 36       NaN    NaN   NaN  ...         NaN      NaN       NaN
# 39       NaN    NaN   NaN  ...         NaN      NaN       NaN
# 397      NaN    NaN   NaN  ...         NaN      NaN       NaN
# 400      NaN    NaN   NaN  ...         NaN      NaN       NaN
# 403      NaN    NaN   NaN  ...         NaN      NaN       NaN
# 406      NaN    NaN   NaN  ...         NaN      NaN       NaN
# 408      NaN    NaN   NaN  ...         NaN      NaN       NaN
# 412      NaN    NaN   NaN  ...         NaN      NaN       NaN
# 414      NaN    NaN   NaN  ...         NaN      NaN       NaN
# 417      NaN    NaN   NaN  ...         NaN      NaN       NaN
# 419      NaN    NaN   NaN  ...         NaN      NaN       NaN
# 422      NaN    NaN   NaN  ...         NaN      NaN       NaN
# 638      NaN    NaN   NaN  ...         NaN      NaN       NaN
# 689      NaN    NaN   NaN  ...         NaN      NaN       NaN
# 690      NaN    NaN   NaN  ...         NaN      NaN       NaN
# 692      NaN    NaN   NaN  ...         NaN      NaN       NaN
# 693      NaN    NaN   NaN  ...         NaN      NaN       NaN
# 694      NaN    NaN   NaN  ...         NaN      NaN       NaN
# 695      NaN    NaN   NaN  ...         NaN      NaN       NaN
# 696      NaN    NaN   NaN  ...         NaN      NaN       NaN
# 698      NaN    NaN   NaN  ...         NaN      NaN       NaN
# 699      NaN    NaN   NaN  ...         NaN      NaN       NaN
# 700      NaN    NaN   NaN  ...         NaN      NaN       NaN
#
#                                                command tpu_count_running  \
# 16   python main_ray.py --batch_size 8 --lr 0.1 --m...               NaN
# 19   python main_ray.py --batch_size 8 --lr 0.1 --m...               NaN
# 21   python main_ray.py --batch_size 8 --lr 0.1 --m...               NaN
# 24   python main_ray.py --batch_size 8 --lr 0.1 --m...               NaN
# 26   python main_ray.py --batch_size 8 --lr 0.1 --m...               NaN
# 29   python main_ray.py --batch_size 8 --lr 0.1 --m...               NaN
# 31   python main_ray.py --batch_size 8 --lr 0.1 --m...               NaN
# 34   python main_ray.py --batch_size 8 --lr 0.1 --m...               NaN
# 36   python main_ray.py --batch_size 8 --lr 0.1 --m...               NaN
# 39   python main_ray.py --batch_size 8 --lr 0.1 --m...               NaN
# 397  python main_ray.py --batch_size 128 --lr 0.3 -...               NaN
# 400  python main_ray.py --batch_size 128 --lr 0.3 -...               NaN
# 403  python main_ray.py --batch_size 128 --lr 0.3 -...               NaN
# 406  python main_ray.py --batch_size 128 --lr 0.3 -...               NaN
# 408  python main_ray.py --batch_size 128 --lr 0.3 -...               NaN
# 412  python main_ray.py --batch_size 128 --lr 0.3 -...               NaN
# 414  python main_ray.py --batch_size 128 --lr 0.3 -...               NaN
# 417  python main_ray.py --batch_size 128 --lr 0.3 -...               NaN
# 419  python main_ray.py --batch_size 128 --lr 0.3 -...               NaN
# 422  python main_ray.py --batch_size 128 --lr 0.3 -...               NaN
# 638  python main_ray.py --batch_size 512 --lr 1.0 -...               NaN
# 689  python main_ray.py --batch_size 1024 --lr 1.0 ...               NaN
# 690  python main_ray.py --batch_size 1024 --lr 1.0 ...               NaN
# 692  python main_ray.py --batch_size 1024 --lr 1.0 ...               NaN
# 693  python main_ray.py --batch_size 1024 --lr 1.0 ...               NaN
# 694  python main_ray.py --batch_size 1024 --lr 1.0 ...               NaN
# 695  python main_ray.py --batch_size 1024 --lr 2.0 ...               NaN
# 696  python main_ray.py --batch_size 1024 --lr 2.0 ...               NaN
# 698  python main_ray.py --batch_size 1024 --lr 2.0 ...               NaN
# 699  python main_ray.py --batch_size 1024 --lr 2.0 ...               NaN
# 700  python main_ray.py --batch_size 1024 --lr 2.0 ...               NaN
#
#     is_running target_steps  is_needed is_done  resume_command
# 16       False      80000.0       True   False            None
# 19       False      80000.0       True   False            None
# 21       False      80000.0       True   False            None
# 24       False      80000.0       True   False            None
# 26       False      80000.0       True   False            None
# 29       False      80000.0       True   False            None
# 31       False      80000.0       True   False            None
# 34       False      80000.0       True   False            None
# 36       False      80000.0       True   False            None
# 39       False      80000.0       True   False            None
# 397      False      80000.0       True   False            None
# 400      False      80000.0       True   False            None
# 403      False      80000.0       True   False            None
# 406      False      80000.0       True   False            None
# 408      False      80000.0       True   False            None
# 412      False      80000.0       True   False            None
# 414      False      80000.0       True   False            None
# 417      False      80000.0       True   False            None
# 419      False      80000.0       True   False            None
# 422      False      80000.0       True   False            None
# 638      False      40000.0       True   False            None
# 689      False      40000.0       True   False            None
# 690      False      40000.0       True   False            None
# 692      False      40000.0       True   False            None
# 693      False      40000.0       True   False            None
# 694      False      40000.0       True   False            None
# 695      False      40000.0       True   False            None
# 696      False      40000.0       True   False            None
# 698      False      40000.0       True   False            None
# 699      False      40000.0       True   False            None
# 700      False      40000.0       True   False            None
#
# [31 rows x 21 columns]

# %%
print(interrupted_df.groupby(["batch_size", "layers", "hidden_size"]).size())
# Out:
# batch_size  layers  hidden_size
# 8.0         10.0    640.0           5
#             20.0    1536.0          5
# 16.0        10.0    640.0          10
#             20.0    1536.0         10
# 32.0        10.0    640.0          15
#             20.0    1536.0         15
# 64.0        10.0    640.0          12
#             16.0    1024.0          1
#             20.0    1536.0         14
# 128.0       10.0    640.0          10
#             16.0    1024.0          1
#             20.0    1536.0          1
# 256.0       10.0    640.0           3
#             16.0    1024.0          6
# 512.0       10.0    640.0          12
#             12.0    768.0           8
#             20.0    1536.0         15
# dtype: int64

# %%
print(inprogress_df.groupby(["batch_size", "layers", "hidden_size"]).size())
# Out:
# Series([], dtype: int64)

# %%
print(missing_df.groupby(["batch_size", "layers", "hidden_size"]).size())
# Out:
# batch_size  layers  hidden_size
# 8.0         10.0    640.0           5
#             20.0    1536.0          5
# 128.0       10.0    640.0           5
#             20.0    1536.0          5
# 512.0       10.0    640.0           1
# 1024.0      20.0    1536.0         10
# dtype: int64

# %%
print(interrupted_df.loc[(interrupted_df["tpu_zone"] != "us-east5-a")].groupby(["tpu_zone", "batch_size"]).size())
# Out:
# tpu_zone           batch_size
# asia-northeast1-b  8.0            4
#                    16.0           7
#                    32.0          11
#                    64.0          12
#                    128.0          2
# europe-west4-a     8.0            6
#                    16.0          13
#                    32.0           8
#                    64.0           4
#                    128.0          3
#                    256.0          4
#                    512.0         10
# us-central1-a      128.0          1
#                    256.0          1
# us-east1-d         32.0           4
#                    64.0           3
#                    128.0          2
# us-east5-b         32.0           7
#                    64.0           8
#                    128.0          4
#                    256.0          4
#                    512.0         10
# dtype: int64

# %%
print("\n".join(interrupted_df.loc[interrupted_df["tpu_zone"] == "us-east5-a"].sort_values(["batch_size", "layers"])["resume_command"].values))
# Out:
# ray job submit --no-wait --address "$RAY_US_EAST5_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v5p-64 TPU_POD_COUNT=1 python main_ray.py --batch_size 512 --micro_batch_size 256 --lr 1.0 --max_training_steps 80000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=512-lr=1.0-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l20_d1536,noise_low_uniform --resume_wandb_id 13o58qup
# ray job submit --no-wait --address "$RAY_US_EAST5_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v5p-64 TPU_POD_COUNT=1 python main_ray.py --batch_size 512 --micro_batch_size 256 --lr 0.5 --max_training_steps 80000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=512-lr=0.5-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l20_d1536,noise_mask --resume_wandb_id d4oru6tb
# ray job submit --no-wait --address "$RAY_US_EAST5_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v5p-64 TPU_POD_COUNT=1 python main_ray.py --batch_size 512 --micro_batch_size 256 --lr 0.5 --max_training_steps 80000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=512-lr=0.5-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l20_d1536,noise_low_uniform --resume_wandb_id 8h6l59ek
# ray job submit --no-wait --address "$RAY_US_EAST5_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v5p-64 TPU_POD_COUNT=1 python main_ray.py --batch_size 512 --micro_batch_size 256 --lr 0.5 --max_training_steps 80000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=512-lr=0.5-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l20_d1536,noise_balanced --resume_wandb_id n6lrkujp
# ray job submit --no-wait --address "$RAY_US_EAST5_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v5p-64 TPU_POD_COUNT=1 python main_ray.py --batch_size 512 --micro_batch_size 256 --lr 0.5 --max_training_steps 80000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=512-lr=0.5-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l20_d1536,noise_high_uniform --resume_wandb_id n7pgs3i1
# ray job submit --no-wait --address "$RAY_US_EAST5_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v5p-64 TPU_POD_COUNT=1 python main_ray.py --batch_size 512 --micro_batch_size 256 --lr 0.5 --max_training_steps 80000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=512-lr=0.5-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l20_d1536,noise_uniform --resume_wandb_id ufi27xdz
# ray job submit --no-wait --address "$RAY_US_EAST5_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v5p-64 TPU_POD_COUNT=1 python main_ray.py --batch_size 512 --micro_batch_size 256 --lr 1.0 --max_training_steps 80000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=512-lr=1.0-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l20_d1536,noise_mask --resume_wandb_id ai4ygxz1
# ray job submit --no-wait --address "$RAY_US_EAST5_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v5p-64 TPU_POD_COUNT=1 python main_ray.py --batch_size 512 --micro_batch_size 256 --lr 1.0 --max_training_steps 80000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=512-lr=1.0-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l20_d1536,noise_balanced --resume_wandb_id dqhqb67a
# ray job submit --no-wait --address "$RAY_US_EAST5_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v5p-64 TPU_POD_COUNT=1 python main_ray.py --batch_size 512 --micro_batch_size 256 --lr 1.0 --max_training_steps 80000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=512-lr=1.0-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l20_d1536,noise_high_uniform --resume_wandb_id 036o24u3
# ray job submit --no-wait --address "$RAY_US_EAST5_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v5p-64 TPU_POD_COUNT=1 python main_ray.py --batch_size 512 --micro_batch_size 256 --lr 1.0 --max_training_steps 80000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=512-lr=1.0-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l20_d1536,noise_uniform --resume_wandb_id a4ykf0bq
# ray job submit --no-wait --address "$RAY_US_EAST5_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v5p-64 TPU_POD_COUNT=1 python main_ray.py --batch_size 512 --micro_batch_size 256 --lr 2.0 --max_training_steps 80000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=512-lr=2.0-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l20_d1536,noise_mask --resume_wandb_id 5szviyum
# ray job submit --no-wait --address "$RAY_US_EAST5_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v5p-64 TPU_POD_COUNT=1 python main_ray.py --batch_size 512 --micro_batch_size 256 --lr 2.0 --max_training_steps 80000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=512-lr=2.0-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l20_d1536,noise_low_uniform --resume_wandb_id dlx23463
# ray job submit --no-wait --address "$RAY_US_EAST5_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v5p-64 TPU_POD_COUNT=1 python main_ray.py --batch_size 512 --micro_batch_size 256 --lr 2.0 --max_training_steps 80000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=512-lr=2.0-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l20_d1536,noise_balanced --resume_wandb_id 572fwh4p
# ray job submit --no-wait --address "$RAY_US_EAST5_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v5p-64 TPU_POD_COUNT=1 python main_ray.py --batch_size 512 --micro_batch_size 256 --lr 2.0 --max_training_steps 80000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=512-lr=2.0-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l20_d1536,noise_high_uniform --resume_wandb_id 6o8qxmb0
# ray job submit --no-wait --address "$RAY_US_EAST5_A" --working-dir . --runtime-env-json='{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}' -- TPU_VERSION=v5p-64 TPU_POD_COUNT=1 python main_ray.py --batch_size 512 --micro_batch_size 256 --lr 2.0 --max_training_steps 80000 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=512-lr=2.0-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l20_d1536,noise_uniform --resume_wandb_id e20iiyum

# %%
# print("\n".join(df.loc[(df["status"] == "missing") & (df["batch_size"] == 256)]["command"].values))
print("\n".join(interrupted_df.loc[interrupted_df["batch_size"] > 1].sort_values(["batch_size", "layers"])["command"].values))
# Out:
# python main_ray.py --batch_size 8 --lr 0.3 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=8-lr=0.3-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l10_d640,noise_mask
# python main_ray.py --batch_size 8 --lr 0.3 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=8-lr=0.3-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l10_d640,noise_low_uniform
# python main_ray.py --batch_size 8 --lr 0.3 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=8-lr=0.3-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l10_d640,noise_balanced
# python main_ray.py --batch_size 8 --lr 0.3 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=8-lr=0.3-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l10_d640,noise_high_uniform
# python main_ray.py --batch_size 8 --lr 0.3 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=8-lr=0.3-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l10_d640,noise_uniform
# python main_ray.py --batch_size 8 --lr 0.3 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=8-lr=0.3-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l20_d1536,noise_mask
# python main_ray.py --batch_size 8 --lr 0.3 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=8-lr=0.3-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l20_d1536,noise_low_uniform
# python main_ray.py --batch_size 8 --lr 0.3 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=8-lr=0.3-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l20_d1536,noise_balanced
# python main_ray.py --batch_size 8 --lr 0.3 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=8-lr=0.3-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l20_d1536,noise_high_uniform
# python main_ray.py --batch_size 8 --lr 0.3 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=8-lr=0.3-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l20_d1536,noise_uniform
# python main_ray.py --batch_size 16 --lr 0.3 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=16-lr=0.3-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l10_d640,noise_mask
# python main_ray.py --batch_size 16 --lr 0.3 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=16-lr=0.3-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l10_d640,noise_low_uniform
# python main_ray.py --batch_size 16 --lr 0.3 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=16-lr=0.3-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l10_d640,noise_balanced
# python main_ray.py --batch_size 16 --lr 0.3 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=16-lr=0.3-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l10_d640,noise_high_uniform
# python main_ray.py --batch_size 16 --lr 0.3 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=16-lr=0.3-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l10_d640,noise_uniform
# python main_ray.py --batch_size 16 --lr 0.5 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=16-lr=0.5-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l10_d640,noise_mask
# python main_ray.py --batch_size 16 --lr 0.5 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=16-lr=0.5-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l10_d640,noise_low_uniform
# python main_ray.py --batch_size 16 --lr 0.5 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=16-lr=0.5-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l10_d640,noise_balanced
# python main_ray.py --batch_size 16 --lr 0.5 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=16-lr=0.5-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l10_d640,noise_high_uniform
# python main_ray.py --batch_size 16 --lr 0.5 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=16-lr=0.5-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l10_d640,noise_uniform
# python main_ray.py --batch_size 16 --lr 0.3 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=16-lr=0.3-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l20_d1536,noise_mask
# python main_ray.py --batch_size 16 --lr 0.3 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=16-lr=0.3-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l20_d1536,noise_low_uniform
# python main_ray.py --batch_size 16 --lr 0.3 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=16-lr=0.3-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l20_d1536,noise_balanced
# python main_ray.py --batch_size 16 --lr 0.3 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=16-lr=0.3-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l20_d1536,noise_high_uniform
# python main_ray.py --batch_size 16 --lr 0.3 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=16-lr=0.3-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l20_d1536,noise_uniform
# python main_ray.py --batch_size 16 --lr 0.5 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=16-lr=0.5-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l20_d1536,noise_mask
# python main_ray.py --batch_size 16 --lr 0.5 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=16-lr=0.5-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l20_d1536,noise_low_uniform
# python main_ray.py --batch_size 16 --lr 0.5 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=16-lr=0.5-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l20_d1536,noise_balanced
# python main_ray.py --batch_size 16 --lr 0.5 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=16-lr=0.5-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l20_d1536,noise_high_uniform
# python main_ray.py --batch_size 16 --lr 0.5 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=16-lr=0.5-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l20_d1536,noise_uniform
# python main_ray.py --batch_size 32 --lr 0.2 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=32-lr=0.2-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l10_d640,noise_mask
# python main_ray.py --batch_size 32 --lr 0.2 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=32-lr=0.2-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l10_d640,noise_low_uniform
# python main_ray.py --batch_size 32 --lr 0.2 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=32-lr=0.2-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l10_d640,noise_balanced
# python main_ray.py --batch_size 32 --lr 0.2 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=32-lr=0.2-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l10_d640,noise_high_uniform
# python main_ray.py --batch_size 32 --lr 0.2 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=32-lr=0.2-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l10_d640,noise_uniform
# python main_ray.py --batch_size 32 --lr 0.3 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=32-lr=0.3-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l10_d640,noise_mask
# python main_ray.py --batch_size 32 --lr 0.3 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=32-lr=0.3-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l10_d640,noise_low_uniform
# python main_ray.py --batch_size 32 --lr 0.3 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=32-lr=0.3-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l10_d640,noise_balanced
# python main_ray.py --batch_size 32 --lr 0.3 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=32-lr=0.3-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l10_d640,noise_high_uniform
# python main_ray.py --batch_size 32 --lr 0.3 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=32-lr=0.3-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l10_d640,noise_uniform
# python main_ray.py --batch_size 32 --lr 0.5 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=32-lr=0.5-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l10_d640,noise_mask
# python main_ray.py --batch_size 32 --lr 0.5 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=32-lr=0.5-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l10_d640,noise_low_uniform
# python main_ray.py --batch_size 32 --lr 0.5 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=32-lr=0.5-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l10_d640,noise_balanced
# python main_ray.py --batch_size 32 --lr 0.5 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=32-lr=0.5-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l10_d640,noise_high_uniform
# python main_ray.py --batch_size 32 --lr 0.5 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=32-lr=0.5-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l10_d640,noise_uniform
# python main_ray.py --batch_size 32 --lr 0.2 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=32-lr=0.2-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l20_d1536,noise_mask
# python main_ray.py --batch_size 32 --lr 0.2 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=32-lr=0.2-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l20_d1536,noise_low_uniform
# python main_ray.py --batch_size 32 --lr 0.2 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=32-lr=0.2-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l20_d1536,noise_balanced
# python main_ray.py --batch_size 32 --lr 0.2 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=32-lr=0.2-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l20_d1536,noise_high_uniform
# python main_ray.py --batch_size 32 --lr 0.2 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=32-lr=0.2-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l20_d1536,noise_uniform
# python main_ray.py --batch_size 32 --lr 0.3 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=32-lr=0.3-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l20_d1536,noise_mask
# python main_ray.py --batch_size 32 --lr 0.3 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=32-lr=0.3-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l20_d1536,noise_low_uniform
# python main_ray.py --batch_size 32 --lr 0.3 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=32-lr=0.3-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l20_d1536,noise_balanced
# python main_ray.py --batch_size 32 --lr 0.3 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=32-lr=0.3-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l20_d1536,noise_high_uniform
# python main_ray.py --batch_size 32 --lr 0.3 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=32-lr=0.3-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l20_d1536,noise_uniform
# python main_ray.py --batch_size 32 --lr 0.5 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=32-lr=0.5-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l20_d1536,noise_mask
# python main_ray.py --batch_size 32 --lr 0.5 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=32-lr=0.5-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l20_d1536,noise_low_uniform
# python main_ray.py --batch_size 32 --lr 0.5 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=32-lr=0.5-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l20_d1536,noise_balanced
# python main_ray.py --batch_size 32 --lr 0.5 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=32-lr=0.5-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l20_d1536,noise_high_uniform
# python main_ray.py --batch_size 32 --lr 0.5 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=32-lr=0.5-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l20_d1536,noise_uniform
# python main_ray.py --batch_size 64 --lr 0.3 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=64-lr=0.3-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l10_d640,noise_balanced
# python main_ray.py --batch_size 64 --lr 0.3 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=64-lr=0.3-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l10_d640,noise_low_uniform
# python main_ray.py --batch_size 64 --lr 0.5 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=64-lr=0.5-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l10_d640,noise_mask
# python main_ray.py --batch_size 64 --lr 0.5 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=64-lr=0.5-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l10_d640,noise_low_uniform
# python main_ray.py --batch_size 64 --lr 0.5 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=64-lr=0.5-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l10_d640,noise_balanced
# python main_ray.py --batch_size 64 --lr 0.5 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=64-lr=0.5-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l10_d640,noise_high_uniform
# python main_ray.py --batch_size 64 --lr 0.5 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=64-lr=0.5-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l10_d640,noise_uniform
# python main_ray.py --batch_size 64 --lr 1.0 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=64-lr=1.0-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l10_d640,noise_mask
# python main_ray.py --batch_size 64 --lr 1.0 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=64-lr=1.0-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l10_d640,noise_low_uniform
# python main_ray.py --batch_size 64 --lr 1.0 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=64-lr=1.0-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l10_d640,noise_balanced
# python main_ray.py --batch_size 64 --lr 1.0 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=64-lr=1.0-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l10_d640,noise_high_uniform
# python main_ray.py --batch_size 64 --lr 1.0 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=64-lr=1.0-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l10_d640,noise_uniform
# python main_ray.py --batch_size 64 --lr 0.3 --max_training_steps 80000.0 --num_layers 16 --hidden_size 1024 --num_attn_heads 16 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L16-D1024-H16-N2048-bs=64-lr=0.3-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l16_d1024,noise_balanced
# python main_ray.py --batch_size 64 --lr 0.3 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=64-lr=0.3-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l20_d1536,noise_uniform
# python main_ray.py --batch_size 64 --lr 0.3 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=64-lr=0.3-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l20_d1536,noise_balanced
# python main_ray.py --batch_size 64 --lr 0.3 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=64-lr=0.3-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l20_d1536,noise_low_uniform
# python main_ray.py --batch_size 64 --lr 0.3 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=64-lr=0.3-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l20_d1536,noise_high_uniform
# python main_ray.py --batch_size 64 --lr 0.5 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=64-lr=0.5-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l20_d1536,noise_mask
# python main_ray.py --batch_size 64 --lr 0.5 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=64-lr=0.5-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l20_d1536,noise_low_uniform
# python main_ray.py --batch_size 64 --lr 0.5 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=64-lr=0.5-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l20_d1536,noise_balanced
# python main_ray.py --batch_size 64 --lr 0.5 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=64-lr=0.5-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l20_d1536,noise_high_uniform
# python main_ray.py --batch_size 64 --lr 0.5 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=64-lr=0.5-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l20_d1536,noise_uniform
# python main_ray.py --batch_size 64 --lr 1.0 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=64-lr=1.0-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l20_d1536,noise_mask
# python main_ray.py --batch_size 64 --lr 1.0 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=64-lr=1.0-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l20_d1536,noise_low_uniform
# python main_ray.py --batch_size 64 --lr 1.0 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=64-lr=1.0-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l20_d1536,noise_balanced
# python main_ray.py --batch_size 64 --lr 1.0 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=64-lr=1.0-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l20_d1536,noise_high_uniform
# python main_ray.py --batch_size 64 --lr 1.0 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=64-lr=1.0-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l20_d1536,noise_uniform
# python main_ray.py --batch_size 128 --lr 0.5 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=128-lr=0.5-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l10_d640,noise_mask
# python main_ray.py --batch_size 128 --lr 0.5 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=128-lr=0.5-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l10_d640,noise_low_uniform
# python main_ray.py --batch_size 128 --lr 0.5 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=128-lr=0.5-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l10_d640,noise_balanced
# python main_ray.py --batch_size 128 --lr 0.5 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=128-lr=0.5-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l10_d640,noise_high_uniform
# python main_ray.py --batch_size 128 --lr 0.5 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=128-lr=0.5-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l10_d640,noise_uniform
# python main_ray.py --batch_size 128 --lr 1.0 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=128-lr=1.0-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l10_d640,noise_mask
# python main_ray.py --batch_size 128 --lr 1.0 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=128-lr=1.0-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l10_d640,noise_low_uniform
# python main_ray.py --batch_size 128 --lr 1.0 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=128-lr=1.0-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l10_d640,noise_balanced
# python main_ray.py --batch_size 128 --lr 1.0 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=128-lr=1.0-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l10_d640,noise_high_uniform
# python main_ray.py --batch_size 128 --lr 1.0 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=128-lr=1.0-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l10_d640,noise_uniform
# python main_ray.py --batch_size 128 --lr 0.3 --max_training_steps 80000.0 --num_layers 16 --hidden_size 1024 --num_attn_heads 16 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L16-D1024-H16-N2048-bs=128-lr=0.3-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l16_d1024,noise_low_uniform
# python main_ray.py --batch_size 128 --lr 1.0 --max_training_steps 80000.0 --num_layers 20 --hidden_size 1536 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.99 --no-break_on_nan --wandb_name gidd-L20-D1536-H24-N2048-bs=128-lr=1.0-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l20_d1536,noise_high_uniform
# python main_ray.py --batch_size 256 --lr 1.0 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=256-lr=1.0-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l10_d640,noise_balanced
# python main_ray.py --batch_size 256 --lr 1.0 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=256-lr=1.0-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l10_d640,noise_uniform
# python main_ray.py --batch_size 256 --lr 1.0 --max_training_steps 80000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=256-lr=1.0-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l10_d640,noise_high_uniform
# python main_ray.py --batch_size 256 --lr 0.5 --max_training_steps 80000.0 --num_layers 16 --hidden_size 1024 --num_attn_heads 16 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L16-D1024-H16-N2048-bs=256-lr=0.5-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l16_d1024,noise_mask
# python main_ray.py --batch_size 256 --lr 1.0 --max_training_steps 80000.0 --num_layers 16 --hidden_size 1024 --num_attn_heads 16 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L16-D1024-H16-N2048-bs=256-lr=1.0-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l16_d1024,noise_high_uniform
# python main_ray.py --batch_size 256 --lr 0.5 --max_training_steps 80000.0 --num_layers 16 --hidden_size 1024 --num_attn_heads 16 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L16-D1024-H16-N2048-bs=256-lr=0.5-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l16_d1024,noise_high_uniform
# python main_ray.py --batch_size 256 --lr 0.5 --max_training_steps 80000.0 --num_layers 16 --hidden_size 1024 --num_attn_heads 16 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L16-D1024-H16-N2048-bs=256-lr=0.5-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l16_d1024,noise_uniform
# python main_ray.py --batch_size 256 --lr 0.5 --max_training_steps 80000.0 --num_layers 16 --hidden_size 1024 --num_attn_heads 16 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L16-D1024-H16-N2048-bs=256-lr=0.5-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l16_d1024,noise_balanced
# python main_ray.py --batch_size 256 --lr 1.0 --max_training_steps 80000.0 --num_layers 16 --hidden_size 1024 --num_attn_heads 16 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L16-D1024-H16-N2048-bs=256-lr=1.0-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l16_d1024,noise_low_uniform
# python main_ray.py --batch_size 512 --lr 0.5 --max_training_steps 40000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=512-lr=0.5-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l10_d640,noise_mask
# python main_ray.py --batch_size 512 --lr 0.5 --max_training_steps 40000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=512-lr=0.5-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l10_d640,noise_balanced
# python main_ray.py --batch_size 512 --lr 0.5 --max_training_steps 40000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=512-lr=0.5-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l10_d640,noise_uniform
# python main_ray.py --batch_size 512 --lr 1.0 --max_training_steps 40000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=512-lr=1.0-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l10_d640,noise_mask
# python main_ray.py --batch_size 512 --lr 1.0 --max_training_steps 40000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=512-lr=1.0-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l10_d640,noise_low_uniform
# python main_ray.py --batch_size 512 --lr 2.0 --max_training_steps 40000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=512-lr=2.0-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l10_d640,noise_mask
# python main_ray.py --batch_size 512 --lr 2.0 --max_training_steps 40000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=512-lr=2.0-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l10_d640,noise_balanced
# python main_ray.py --batch_size 512 --lr 2.0 --max_training_steps 40000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=512-lr=2.0-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l10_d640,noise_uniform
# python main_ray.py --batch_size 512 --lr 2.0 --max_training_steps 40000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=512-lr=2.0-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l10_d640,noise_low_uniform
# python main_ray.py --batch_size 512 --lr 0.5 --max_training_steps 40000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=512-lr=0.5-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l10_d640,noise_low_uniform
# python main_ray.py --batch_size 512 --lr 2.0 --max_training_steps 40000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=512-lr=2.0-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l10_d640,noise_high_uniform
# python main_ray.py --batch_size 512 --lr 0.5 --max_training_steps 40000.0 --num_layers 10 --hidden_size 640 --num_attn_heads 10 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L10-D640-H10-N2048-bs=512-lr=0.5-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l10_d640,noise_high_uniform
# python main_ray.py --batch_size 512 --lr 2.0 --max_training_steps 40000.0 --num_layers 12 --hidden_size 768 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L12-D768-H12-N2048-bs=512-lr=2.0-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l12_d768,noise_low_uniform
# python main_ray.py --batch_size 512 --lr 1.0 --max_training_steps 40000.0 --num_layers 12 --hidden_size 768 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L12-D768-H12-N2048-bs=512-lr=1.0-noise_low_uniform --hybrid_mixing_shift -2.0 --wandb_tags crit_bs_l12_d768,noise_low_uniform
# python main_ray.py --batch_size 512 --lr 1.0 --max_training_steps 40000.0 --num_layers 12 --hidden_size 768 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L12-D768-H12-N2048-bs=512-lr=1.0-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l12_d768,noise_balanced
# python main_ray.py --batch_size 512 --lr 2.0 --max_training_steps 40000.0 --num_layers 12 --hidden_size 768 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L12-D768-H12-N2048-bs=512-lr=2.0-noise_balanced --hybrid_mixing_shift 0.0 --wandb_tags crit_bs_l12_d768,noise_balanced
# python main_ray.py --batch_size 512 --lr 2.0 --max_training_steps 40000.0 --num_layers 12 --hidden_size 768 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L12-D768-H12-N2048-bs=512-lr=2.0-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l12_d768,noise_uniform
# python main_ray.py --batch_size 512 --lr 2.0 --max_training_steps 40000.0 --num_layers 12 --hidden_size 768 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L12-D768-H12-N2048-bs=512-lr=2.0-noise_high_uniform --hybrid_mixing_shift 2.0 --wandb_tags crit_bs_l12_d768,noise_high_uniform
# python main_ray.py --batch_size 512 --lr 1.0 --max_training_steps 40000.0 --num_layers 12 --hidden_size 768 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L12-D768-H12-N2048-bs=512-lr=1.0-noise_uniform --hybrid_mixing_shift 1000.0 --wandb_tags crit_bs_l12_d768,noise_uniform
# python main_ray.py --batch_size 512 --lr 1.0 --max_training_steps 40000.0 --num_layers 12 --hidden_size 768 --num_attn_heads 12 --max_seq_len 2048 --cooldown_steps 0.0 --beta2 0.98 --no-break_on_nan --wandb_name gidd-L12-D768-H12-N2048-bs=512-lr=1.0-noise_mask --hybrid_mixing_shift -1000.0 --wandb_tags crit_bs_l12_d768,noise_mask

# %%
# scaffold = """ray job submit --no-wait --address "{address}" --working-dir . --runtime-env-json='{{"py_modules":["../EasyDeL/easydel","../eformer/eformer","../orbax/checkpoint/orbax"]}}' -- TPU_VERSION={tpu_version} TPU_POD_COUNT={tpu_count} python"""

# zone_to_address = {
#     "asia-northeast1-b": "$RAY_ASIA_NORTHEAST1_B",
#     "europe-west4-a": "$RAY_EU_WEST4_A",
#     "us-central1-a": "$RAY_US_CENTRAL1_A",
#     "us-east1-d": "$RAY_US_EAST1_D",
#     "us-east5-a": "$RAY_US_EAST5_A",
#     "us-east5-b": "$RAY_US_EAST5_B",
# }

# def format_resume_command(row):
#     base_cmd = row["command"]
#     wandb_id = row["wandb_id"]
#     tpu_zone = row["tpu_zone"]
#     tpu_version = row["tpu_version"]
#     tpu_count = row["tpu_count"]
#     if "--resume_wandb_id" not in base_cmd and not pd.isna(wandb_id):
#         base_cmd = f"{base_cmd} --resume_wandb_id {wandb_id}"
#     address = zone_to_address.get(tpu_zone, "$RAY_US_EAST1_D")
#     return scaffold.format(address=address, tpu_version=tpu_version, tpu_count=tpu_count) + " " + base_cmd.strip()

# commands = df.loc[(df["status"] == "crashed") & (df["is_running"] != True) & (df["is_needed"])].apply(format_resume_command, axis=1)

# with open("resume_commands.txt", "w") as f:
#     f.write("\n".join(commands.values))
# print("\n".join(commands.values))
